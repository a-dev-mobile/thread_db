# %%
import numpy as np
import pandas as pd
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db

# %%
cred = credentials.Certificate('/Users/dmitriytrofimov/DEV/flutter/project/MY_GITHUB/thread_db/fire_key/dev-threadfon-firebase-adminsdk-bitoo-1e1b8b42d3.json')

if not firebase_admin._apps:
    firebase_admin.initialize_app(cred, {'databaseURL': 'https://dev-threadfon-default-rtdb.asia-southeast1.firebasedatabase.app/'})

# %% [markdown]
# # m Thread - gost_8724_2002_diam_pitch

# %%
csv = '/Users/dmitriytrofimov/DEV/flutter/project/MY_GITHUB/thread_db/csv/m Thread - gost_8724_2002_diam_pitch.csv'

df_csv = pd.read_csv(csv, sep=',', error_bad_lines=False,index_col=False, dtype='unicode')

df_csv = df_csv.astype(object).replace(np.nan, '')
# Out:
# /Users/dmitriytrofimov/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
path = '/thread/metric/ru/standart/gost_8724_2002/diam_pitch'
database_ref = db.reference(path)

database_ref.delete()

# %%
d={}
class_id = {}
i = 0
df = df_csv

sum_row = df.shape[0]

for index, row in df.iterrows():
    print('----------------------------')
    i = i + 1
    print('{0} = {1}'.format(i, sum_row))
 
    d['id'] =row['id']
    d['range_1'] =row['range_1']
    d['range_2'] =row['range_2']
    d['range_3'] =row['range_3']
    d['coarse_pitch'] =row['coarse_pitch']
    d['pitchs'] =row['pitchs'].split(',')
  
    database_ref = db.reference(path+'/'+d['id']+'.___'+'/')
    database_ref.set(d)
    d.clear()
# Out:
# ----------------------------
# 1 = 147
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hw/ssgm86vj6sqgjz08lb0m6mn40000gn/T/ipykernel_31259/3965284509.py in <module>
#      18     d['pitchs'] =row['pitchs'].split(',')
#      19
# ---> 20     database_ref = db.reference(path+'/'+d['id']+'.___'+'/')
#      21     database_ref.set(d)
#      22     d.clear()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/firebase_admin/db.py in reference(path, app, url)
#      68     service = _utils.get_app_service(app, _DB_ATTRIBUTE, _DatabaseService)
#      69     client = service.get_client(url)
# ---> 70     return Reference(client=client, path=path)
#      71
#      72 def _parse_path(path):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/firebase_admin/db.py in __init__(self, **kwargs)
#     150             self._segments = kwargs.get('segments')
#     151         else:
# ...

# %% [markdown]
# # m Thread - gost_16967-81_diam_pitch

# %%
csv = '/Users/dmitriytrofimov/DEV/flutter/project/MY_GITHUB/thread_db/csv/m Thread - gost_16967-81_diam_pitch.csv'

df_csv = pd.read_csv(csv, sep=',', error_bad_lines=False,index_col=False, dtype='unicode')

df_csv = df_csv.astype(object).replace(np.nan, '')

# %%
path = '/thread/metric/ru/standart/gost_16967_1981/diam_pitch'
database_ref = db.reference(path)

database_ref.delete()

# %%
class_id = {}
i = 0
df = df_csv

sum_row = df.shape[0]

for index, row in df.iterrows():
    print('----------------------------')
    i = i + 1
    print('{0} = {1}'.format(i, sum_row))
 
    d['id'] =row['id']
    d['range_1'] =row['range_1']
    d['range_2'] =row['range_2']
    d['pitchs'] =row['pitchs'].split(',')
  
    database_ref = db.reference(path+'/'+d['id'] +'/')
    database_ref.set(d)
    d.clear()
# Out:
# ----------------------------
# 1 = 270
# ----------------------------
# 2 = 270
# ----------------------------
# 3 = 270
# ----------------------------
# 4 = 270
# ----------------------------
# 5 = 270
# ----------------------------
# 6 = 270
# ----------------------------
# 7 = 270
# ----------------------------
# 8 = 270
# ----------------------------
# 9 = 270
# ----------------------------
# 10 = 270
# ----------------------------
# 11 = 270
# ----------------------------
# 12 = 270
# ----------------------------
# 13 = 270
# ----------------------------
# 14 = 270
# ----------------------------
# 15 = 270
# ----------------------------
# 16 = 270
# ----------------------------
# 17 = 270
# ----------------------------
# 18 = 270
# ----------------------------
# 19 = 270
# ----------------------------
# 20 = 270
# ----------------------------
# 21 = 270
# ----------------------------
# 22 = 270
# ----------------------------
# 23 = 270
# ----------------------------
# 24 = 270
# ...

# %% [markdown]
# # m Thread - gost_9150_2002_profile

# %%
csv = '/Users/dmitriytrofimov/DEV/flutter/project/MY_GITHUB/thread_db/csv/m Thread - gost_9150_2002_profile.csv'

df_csv = pd.read_csv(csv, sep=',', error_bad_lines=False,index_col=False, dtype='unicode')

df_csv = df_csv.astype(object).replace(np.nan, '')

# %%
path = '/thread/metric/ru/standart/gost_9150_2002/profile'
database_ref = db.reference(path)

database_ref.delete()

# %%
class_id = {}
i = 0
df = df_csv

sum_row = df.shape[0]
# id,pitch,h,h_5_8,h_3_8,h_4,h_8
for index, row in df.iterrows():
    print('----------------------------')
    i = i + 1
    print('{0} = {1}'.format(i, sum_row))
 
    d['id'] =row['id']
    d['pitch'] =row['pitch']
    d['h'] =row['h']
    d['h_5_8'] =row['h_5_8']
    d['h_3_8'] =row['h_3_8']
    d['h_4'] =row['h_4']
    d['h_8'] =row['h_8']

  
    database_ref = db.reference(path+'/'+d['id'] +'/')
    database_ref.set(d)
    d.clear()
# Out:
# ----------------------------
# 1 = 33
# ----------------------------
# 2 = 33
# ----------------------------
# 3 = 33
# ----------------------------
# 4 = 33
# ----------------------------
# 5 = 33
# ----------------------------
# 6 = 33
# ----------------------------
# 7 = 33
# ----------------------------
# 8 = 33
# ----------------------------
# 9 = 33
# ----------------------------
# 10 = 33
# ----------------------------
# 11 = 33
# ----------------------------
# 12 = 33
# ----------------------------
# 13 = 33
# ----------------------------
# 14 = 33
# ----------------------------
# 15 = 33
# ----------------------------
# 16 = 33
# ----------------------------
# 17 = 33
# ----------------------------
# 18 = 33
# ----------------------------
# 19 = 33
# ----------------------------
# 20 = 33
# ----------------------------
# 21 = 33
# ----------------------------
# 22 = 33
# ----------------------------
# 23 = 33
# ----------------------------
# 24 = 33
# ...

# %% [markdown]
# # m Thread - gost_9150_2002_profile

# %%
csv = '/Users/dmitriytrofimov/DEV/flutter/project/MY_GITHUB/thread_db/csv/m Thread - gost_24705-2004_dimension.csv'

df_csv = pd.read_csv(csv, sep=',', error_bad_lines=False,index_col=False, dtype='unicode')

df_csv = df_csv.astype(object).replace(np.nan, '')

# %%
path = '/thread/metric/ru/standart/gost_24705_2004/dimension'
database_ref = db.reference(path)

database_ref.delete()

# %%
class_id = {}
i = 0
df = df_csv

sum_row = df.shape[0]
# id,diam,pitch,pitch_diam_d2,minor_diam_d1,minor_diam_d3
for index, row in df.iterrows():
    print('----------------------------')
    i = i + 1
    print('{0} = {1}'.format(i, sum_row))
 
    d['id'] =row['id']
    d['diam'] =row['diam']
    d['pitch'] =row['pitch']
    d['pitch_diam_d2'] =row['pitch_diam_d2']
    d['minor_diam_d1'] =row['minor_diam_d1']
    d['minor_diam_d3'] =row['minor_diam_d3']


  
    database_ref = db.reference(path+'/'+d['id'] +'/')
    database_ref.set(d)
    d.clear()

# %% [markdown]
# # gost_24706-1981_dimension

# %%
csv = '/Users/dmitriytrofimov/DEV/flutter/project/MY_GITHUB/thread_db/csv/m Thread - gost_24706-1981_dimension.csv'

df_csv = pd.read_csv(csv, sep=',', error_bad_lines=False,index_col=False, dtype='unicode')

df_csv = df_csv.astype(object).replace(np.nan, '')

# %%
path = '/thread/metric/ru/standart/gost_24706_1981/dimension'
database_ref = db.reference(path)

database_ref.delete()

# %%
class_id = {}
i = 0
df = df_csv

sum_row = df.shape[0]
#  id,diam,pitch,pitch_diam_d2,minor_diam_d1,minor_diam_d3
for index, row in df.iterrows():
    print('----------------------------')
    i = i + 1
    print('{0} = {1}'.format(i, sum_row))
 
    d['id'] =row['id']
    d['diam'] =row['diam']
    d['pitch'] =row['pitch']
    d['pitch_diam_d2'] =row['pitch_diam_d2']
    d['minor_diam_d1'] =row['minor_diam_d1']
    d['minor_diam_d3'] =row['minor_diam_d3']


  
    database_ref = db.reference(path+'/'+d['id'] +'/')
    database_ref.set(d)
    d.clear()
# Out:
# ----------------------------
# 1 = 439
# ----------------------------
# 2 = 439
# ----------------------------
# 3 = 439
# ----------------------------
# 4 = 439
# ----------------------------
# 5 = 439
# ----------------------------
# 6 = 439
# ----------------------------
# 7 = 439
# ----------------------------
# 8 = 439
# ----------------------------
# 9 = 439
# ----------------------------
# 10 = 439
# ----------------------------
# 11 = 439
# ----------------------------
# 12 = 439
# ----------------------------
# 13 = 439
# ----------------------------
# 14 = 439
# ----------------------------
# 15 = 439
# ----------------------------
# 16 = 439
# ----------------------------
# 17 = 439
# ----------------------------
# 18 = 439
# ----------------------------
# 19 = 439
# ----------------------------
# 20 = 439
# ----------------------------
# 21 = 439
# ----------------------------
# 22 = 439
# ----------------------------
# 23 = 439
# ----------------------------
# 24 = 439
# ...
